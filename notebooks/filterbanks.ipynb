# %%
from matilda.transform import make_filter_bank
from matilda.transform import show_filter_bank
from matilda.transform import get_available

# %%
get_available()
# Out:
# ('dct', 'wlsh', 'slant', 'chebychev')

# %% [markdown]
# # DCT

# %%
dct3x3 = make_filter_bank('dct', n=3)
print(dct3x3.shape)
show_filter_bank(dct3x3)
# Out:
# (3, 3, 1, 9)

# %%
dct4x4 = make_filter_bank('dct', n=4)
print(dct4x4.shape)
show_filter_bank(dct4x4)
# Out:
# (4, 4, 1, 16)

# %%
dct5x5 = make_filter_bank('dct', n=5)
print(dct5x5.shape)
show_filter_bank(dct5x5, figsize=(18, 18))
# Out:
# (5, 5, 1, 25)

# %%
dct5x5 = make_filter_bank('dct', n=5, level=2)
print(dct5x5.shape)
show_filter_bank(dct5x5, figsize=(18, 18))
# Out:
# (5, 5, 1, 3)

# %%
dct5x5 = make_filter_bank('dct', n=5, level=4)
print(dct5x5.shape)
show_filter_bank(dct5x5, figsize=(18, 18))
# Out:
# (5, 5, 1, 10)

# %% [markdown]
# # Slant transform

# %%
slant4x4 = make_filter_bank('slant', n=4)
print(slant4x4.shape)
show_filter_bank(slant4x4)
# Out:
# (4, 4, 1, 16)

# %% [markdown]
# # WALSH

# %%
wlsh4x4 = make_filter_bank('wlsh', n=4)
print(wlsh4x4.shape)
show_filter_bank(wlsh4x4)
# Out:
# (4, 4, 1, 16)

# %% [markdown]
# # CHEBYCHEV

# %%
cheb3x3 = make_filter_bank('chebychev', n=3)
print(cheb3x3.shape)
show_filter_bank(cheb3x3)
# Out:
# (3, 3, 1, 9)
